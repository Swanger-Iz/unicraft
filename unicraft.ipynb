# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns

# %%
name_of_files = [name for name in os.listdir('unicraft/') if name[0] == 'F' or name[0] == 'G']
name_of_files
# Out:
# ['Facebook 2020-2021 Unicraft.xls.xlsx', 'Google 2020-2021 Unicraft.csv.xlsx']

# %%
frames = []
for name in name_of_files:
    frames.append(pd.read_excel('unicraft/' + name, skiprows=1))
frames[0] = frames[0].drop([0,1])
frames[1] = frames[1].drop([0,1])

# %%
frames[0].rename(columns={'Unnamed: 0':'date',
                          'Unnamed: 1': 'expenses',
                         },inplace=True)
frames[0].drop(frames[0].tail(1).index, inplace=True)
frames[0]
# Out:
#    date  expenses Unnamed: 2 Unnamed: 3 Unnamed: 4
# 2   янв  12135.85      26157        214         52
# 3   фев   5225.16       5490         41          5
# 4   мар  27140.07      28213        151         43
# 5   апр   15519.2      18704         95         25
# 6   май  18661.68      37752        316         83
# 7   июн  10731.34      39879        200         52
# 8   июл   3092.88      24280         98         18
# 9   авг   3107.56      28373         97         23
# 10  сен    3002.6      28166         83         16
# 11  окт   2895.12      20510         86         19
# 12  ноя    7709.3      20434        141        354
# 13  дек  12376.35      23980        227         42

# %%
# frames[1] = frames[1].iloc[1: , :]
frames[1].rename(columns={'Unnamed: 0':'date',
                          'Unnamed: 1': 'expenses',
                         }, inplace=True)
frames[1]
# Out:
#                 date     expenses Unnamed: 2 Unnamed: 3 Unnamed: 4
# 2     январь 2021 г.    350196.91       2892       3561     734.52
# 3    февраль 2021 г.    338959.24       3636       2972        484
# 4       март 2021 г.    501737.84       4969       3291        604
# 5     апрель 2021 г.     650590.8       2213       4299    1011.32
# 6        май 2021 г.    582409.04       6814       3863     971.99
# 7       июнь 2021 г.    566744.76       7446       3729    1140.68
# 8       июль 2021 г.    528411.08       9785       3493     839.99
# 9     август 2021 г.    571182.04       9725       3326     794.68
# 10  сентябрь 2021 г.    861336.92       6520       5025    1088.69
# 11   октябрь 2021 г.    934553.24       3428       4742     993.31
# 12    ноябрь 2021 г.    609334.04      10663       3784     509.33
# 13   декабрь 2020 г.    395097.23       3855       3177     463.48
# 14           (пусто)   5274860.64          0          0     255.11
# ...

# %%
# Данные по фейсбуку (мес, сум_затр)
month_facebook = frames[0]['date'].tolist()[:-1]
sum_zatr_facebook = frames[0]['expenses'].tolist()[:-1]
sum_zatr_facebook, month_facebook
# Out:
# ([12135.85,
#   5225.16,
#   27140.07,
#   15519.2,
#   18661.68,
#   10731.34,
#   3092.88,
#   3107.56,
#   3002.6,
#   2895.12,
#   7709.3],
#  ['янв', 'фев', 'мар', 'апр', 'май', 'июн', 'июл', 'авг', 'сен', 'окт', 'ноя'])

# %%
plt.figure(figsize=(20,14))
plt.grid(True)
sns.lineplot(month_facebook, sum_zatr_facebook)
# Out:
# /home/ilgiz/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Данные по гуглу(мес, сум_затр)
month_google = frames[1]['date'].tolist()[:-2]
month_google = [month.split(' ')[0] for month in month_google]

sum_zatr_google = frames[1]['expenses'].tolist()[:-2]
sum_zatr_google, month_google
# Out:
# ([350196.91,
#   338959.24,
#   501737.84,
#   650590.8,
#   582409.04,
#   566744.76,
#   528411.08,
#   571182.04,
#   861336.92,
#   934553.24,
#   609334.04,
#   395097.23],
#  ['январь',
#   'февраль',
#   'март',
#   'апрель',
#   'май',
#   'июнь',
#   'июль',
#   'август',
#   'сентябрь',
#   'октябрь',
#   'ноябрь',
#   'декабрь'])

# %%
plt.figure(figsize=(20,14))
plt.grid(True)
sns.lineplot(month_google, sum_zatr_google)
# Out:
# /home/ilgiz/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
frames[1].drop(frames[1].tail(2).index, inplace=True)
frames[1]
# Out:
#                 date   expenses Unnamed: 2 Unnamed: 3 Unnamed: 4
# 2     январь 2021 г.  350196.91       2892       3561     734.52
# 3    февраль 2021 г.  338959.24       3636       2972        484
# 4       март 2021 г.  501737.84       4969       3291        604
# 5     апрель 2021 г.   650590.8       2213       4299    1011.32
# 6        май 2021 г.  582409.04       6814       3863     971.99
# 7       июнь 2021 г.  566744.76       7446       3729    1140.68
# 8       июль 2021 г.  528411.08       9785       3493     839.99
# 9     август 2021 г.  571182.04       9725       3326     794.68
# 10  сентябрь 2021 г.  861336.92       6520       5025    1088.69
# 11   октябрь 2021 г.  934553.24       3428       4742     993.31
# 12    ноябрь 2021 г.  609334.04      10663       3784     509.33
# 13   декабрь 2020 г.  395097.23       3855       3177     463.48

# %%
# Удаление хвоста
# frames[0].drop(frames[0].tail(1).index,inplace=True)
# frames[1].drop(frames[1].tail(2).index,inplace=True)

# %%
# 1. Общ формат месяца 
# 2. Общ затраты + 
# Посчитать доходы, взять из CRM (сделать группировку, месяц, сум, расх, сум. дох)
# romi

# %%
# Данные по яндексу (мес, сум_затр)
df_yandex = pd.read_excel('unicraft/Yandex 2020-2021 Unciraft.xlsx', skiprows=3)
df_yandex = df_yandex.iloc[1: , :]
df_yandex.drop(df_yandex.tail(3).index,inplace=True)
df_yandex.rename(columns={'Дата':'date', 
                        'Сумма по полю * Расход (руб.)': 'expenses'}, inplace=True)
df_yandex
# Out:
#         date   expenses  Сумма по полю Показы  Сумма по полю Клики  \
# 1   янв 2021  108793,46              191650.0               2087.0
# 2   фев 2021  112774,86              138495.0               1607.0
# 3   мар 2021  136107,41               72654.0               1537.0
# 4   апр 2021  108561,04               61450.0               1249.0
# 5   май 2021  104018,48               74495.0               1074.0
# 6   июн 2021  100234,94               48185.0                976.0
# 7   июл 2021   135466,4               55993.0               1142.0
# 8   авг 2021   185396,4               81954.0               1652.0
# 9   сен 2021  108959,06             3498282.0               7421.0
# 10  окт 2021  123349,32             2021686.0               8472.0
# 11  ноя 2021   83263,81              647526.0               4226.0
#
#     Количество по полю Конверсии
# 1                           17.0
# 2                           17.0
# 3                           16.0
# ...

# %%
month_yandex = df_yandex['expenses'].tolist()
month_yandex = [month.split(' ')[0] for month in month_yandex]
month_yandex = [month.replace(',', '.') for month in month_yandex]
month_yandex = [float(month) for month in month_yandex]
month_yandex
# Out:
# [108793.46,
#  112774.86,
#  136107.41,
#  108561.04,
#  104018.48,
#  100234.94,
#  135466.4,
#  185396.4,
#  108959.06,
#  123349.32,
#  83263.81]

# %%
plt.figure(figsize=(20,14))
plt.grid(True)
#sns.lineplot(data = df_yandex, x = 'Дата', y=('Сумма по полю * Расход (руб.)'.astype(float)))
sns.lineplot(df_yandex['date'], month_yandex)
# Out:
# /home/ilgiz/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date'>

# %%
df_all = pd.concat([frames[0][['date','expenses']],
                   frames[1][['date', 'expenses']],
                   df_yandex[['date', 'expenses']]], )


df_all.insert(2, 'Channel', 'Facebook')

df_all['Channel'][:12] = 'Facebook'
df_all['Channel'][12:24] = 'Google'
df_all['Channel'][24:] = 'Yandex'

df_all['date'] = ([*range(1, 13)] * 3)[:-1]
df_all
# Out:
#     date   expenses   Channel
# 2      1   12135.85  Facebook
# 3      2    5225.16  Facebook
# 4      3   27140.07  Facebook
# 5      4    15519.2  Facebook
# 6      5   18661.68  Facebook
# 7      6   10731.34  Facebook
# 8      7    3092.88  Facebook
# 9      8    3107.56  Facebook
# 10     9     3002.6  Facebook
# 11    10    2895.12  Facebook
# 12    11     7709.3  Facebook
# 13    12   12376.35  Facebook
# 2      1  350196.91    Google
# 3      2  338959.24    Google
# 4      3  501737.84    Google
# 5      4   650590.8    Google
# 6      5  582409.04    Google
# 7      6  566744.76    Google
# 8      7  528411.08    Google
# 9      8  571182.04    Google
# 10     9  861336.92    Google
# 11    10  934553.24    Google
# 12    11  609334.04    Google
# 13    12  395097.23    Google
# 1      1  108793,46    Yandex
# 2      2  112774,86    Yandex
# 3      3  136107,41    Yandex
# 4      4  108561,04    Yandex
# 5      5  104018,48    Yandex
# 6      6  100234,94    Yandex
# ...

# %%
temp = [str(el).replace(',', '.') for el in temp]
temp = [float(el) for el in temp]
df_all['expenses'] = temp

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 2 to 11
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      35 non-null     int64
#  1   expenses  35 non-null     float64
#  2   Channel   35 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df_all.groupby('date')['expenses'].sum().reset_index(name=name)
# Out:
#     date  Google 2020-2021 Unicraft.csv.xlsx
# 0      1                           471126.22
# 1      2                           456959.26
# 2      3                           664985.32
# 3      4                           774671.04
# 4      5                           705089.20
# 5      6                           677711.04
# 6      7                           666970.36
# 7      8                           759686.00
# 8      9                           973298.58
# 9     10                          1060797.68
# 10    11                           700307.15
# 11    12                           407473.58

# %% [markdown]
# ## Расход
#
# ***Общ. расход - 8 319 075.43***

# %%
df_all_groupped = df_all.groupby(by = [df_all['date'], 'Channel'])['expenses'].sum().reset_index(name=name)
df_all_groupped.rename(columns={'Google 2020-2021 Unicraft.csv.xlsx': 'Evenue'}, inplace=True)
df_all_groupped
# Out:
#     date   Channel     Evenue
# 0      1  Facebook   12135.85
# 1      1    Google  350196.91
# 2      1    Yandex  108793.46
# 3      2  Facebook    5225.16
# 4      2    Google  338959.24
# 5      2    Yandex  112774.86
# 6      3  Facebook   27140.07
# 7      3    Google  501737.84
# 8      3    Yandex  136107.41
# 9      4  Facebook   15519.20
# 10     4    Google  650590.80
# 11     4    Yandex  108561.04
# 12     5  Facebook   18661.68
# 13     5    Google  582409.04
# 14     5    Yandex  104018.48
# 15     6  Facebook   10731.34
# 16     6    Google  566744.76
# 17     6    Yandex  100234.94
# 18     7  Facebook    3092.88
# 19     7    Google  528411.08
# 20     7    Yandex  135466.40
# 21     8  Facebook    3107.56
# 22     8    Google  571182.04
# 23     8    Yandex  185396.40
# 24     9  Facebook    3002.60
# 25     9    Google  861336.92
# 26     9    Yandex  108959.06
# 27    10  Facebook    2895.12
# 28    10    Google  934553.24
# 29    10    Yandex  123349.32
# ...

# %%
df_all_months = df_all.groupby(by = [df_all['date']])['expenses'].sum().reset_index(name=name)
df_all_months.rename(columns={'Google 2020-2021 Unicraft.csv.xlsx': 'Revenue'}, inplace=True)
df_all_months['Revenue'].sum()
# Out:
# 8319075.430000001

# %%
df_revenue = pd.read_excel('unicraft/CRM - Test.xlsx')
print(round(sum(revenue['Зачисление'].tolist()), 2)) # Общий доход
df_revenue
# Out:
# 17789009.64
#     Дата документа Дата операции                  Счёт  Зачисление   код
# 0       2020-11-02    2020-11-02  40702810202500064712     28500.0  6776
# 1       2020-11-04    2020-11-05  40702810202500064712      9652.5  3893
# 2       2020-11-11    2020-11-11  40702810202500064712    304286.0  1665
# 3       2020-11-12    2020-11-12  40702810202500064712     57000.0  4730
# 4       2020-11-16    2020-11-16  40702810202500064712     30781.0  3344
# ..             ...           ...                   ...         ...   ...
# 343     2021-10-27    2021-10-27  40702810202500064712      9900.0  6696
# 344     2021-10-27    2021-10-27  40702810202500064712     14250.0   204
# 345     2021-10-28    2021-10-28  40702810202500064712     17100.0  6776
# 346     2021-10-28    2021-10-29  40702810202500064712     57000.0  4546
# 347     2021-10-29    2021-10-29  40702810202500064712     16723.8  3893
#
# [348 rows x 5 columns]

# %% [markdown]
# ## Income
# ***Общ доход - 17 789 009.64***
# ***ARR***

# %%
df_revenue = df_revenue[revenue['Дата документа'].dt.year==2021]
df_revenue_groupped = df_revenue.groupby(by = [revenue['Дата документа'].dt.month])['Зачисление'].sum().reset_index(name=name)
df_revenue_groupped.rename(columns={'Дата документа':'Date', 
                                    'Google 2020-2021 Unicraft.csv.xlsx': 'Income'}, inplace=True)
df_revenue_groupped
# Out:
#    Date      Income
# 0     1   904582.50
# 1     2  1555403.50
# 2     3  1082010.44
# 3     4  1203843.76
# 4     5  2765879.24
# 5     6  1063447.60
# 6     7  1384351.67
# 7     8  1637219.44
# 8     9  2062832.39
# 9    10  1978708.60

# %%
plt.figure(figsize=(20,14))
plt.grid(True)

sns.lineplot(df_revenue_groupped['Date'], df_revenue_groupped['Income'])
# Out:
# /home/ilgiz/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Income'>

# %%
type(df_all_months), type(df_revenue_groupped['Income'].tolist())
# Out:
# (pandas.core.frame.DataFrame, list)

# %%
# df_revenue_groupped['Income'].tolist() - yandex_evenue / yandex_evenue * 100

def romi(revenue_list, income_list):
    result = []
    for el in range(len(income_list)):
        result.append((income_list[el] - revenue_list[el]) / revenue_list[el] * 100)
    return result

romi(df_all_months['Revenue'].tolist()[:-2], df_revenue_groupped['Income'].tolist())
# Out:
# [92.00427859863119,
#  240.38121910474035,
#  62.71192873851709,
#  55.40064076746691,
#  292.27366409810276,
#  56.91755589520868,
#  107.5581994378281,
#  115.5126512796076,
#  111.94240209412409,
#  86.53025334670794]

# %% [markdown]
# ## Romi

# %%
# ROMI
df_romi = pd.DataFrame({'Month':df_revenue_groupped['Date'],
                        'Romi': romi(df_all_months['Revenue'].tolist()[:-2], df_revenue_groupped['Income'].tolist())})
df_romi
# Out:
#    Month        Romi
# 0      1   92.004279
# 1      2  240.381219
# 2      3   62.711929
# 3      4   55.400641
# 4      5  292.273664
# 5      6   56.917556
# 6      7  107.558199
# 7      8  115.512651
# 8      9  111.942402
# 9     10   86.530253

# %%
plt.figure(figsize=(20,14))
plt.grid(True)

sns.lineplot(df_romi['Month'], df_romi['Romi'])
# Out:
# /home/ilgiz/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Month', ylabel='Romi'>

# %%
# plt.figure(figsize=(20,14))
# plt.grid(True)

#sns.lineplot(df_romi['Month'], df_romi['Romi'])
#sns.lineplot(df_revenue_groupped['Date'], df_revenue_groupped['Income'])

#df_result = df_romi.join(df_revenue_groupped, lsuffix='_df_romi', rsuffix='_df_revenue_groupped')
#temp_res = df_romi.set_index('Month').join(df_revenue_groupped.set_index('Date'))
temp_res = df_romi.join(df_revenue_groupped.set_index('Date'), on='Month')
ress = temp_res.join(df_)

#df_result = df.temp_res.set_index('Month')
# Out:
#    Month        Romi      Income
# 0      1   92.004279   904582.50
# 1      2  240.381219  1555403.50
# 2      3   62.711929  1082010.44
# 3      4   55.400641  1203843.76
# 4      5  292.273664  2765879.24
# 5      6   56.917556  1063447.60
# 6      7  107.558199  1384351.67
# 7      8  115.512651  1637219.44
# 8      9  111.942402  2062832.39
# 9     10   86.530253  1978708.60

# %%
plt.figure(figsize=(20, 14))
plt.grid(True)
plt.title('Evenue')
sns.set_palette("bright")
sns.lineplot(data=df_all_groupped.head(30), x='date', y='Evenue', hue='Channel')
plt.show()

# %%
df_all_groupped.head(30)   # df_romi, df_revenue_groupped
# Out:
#     date   Channel     Evenue
# 0      1  Facebook   12135.85
# 1      1    Google  350196.91
# 2      1    Yandex  108793.46
# 3      2  Facebook    5225.16
# 4      2    Google  338959.24
# 5      2    Yandex  112774.86
# 6      3  Facebook   27140.07
# 7      3    Google  501737.84
# 8      3    Yandex  136107.41
# 9      4  Facebook   15519.20
# 10     4    Google  650590.80
# 11     4    Yandex  108561.04
# 12     5  Facebook   18661.68
# 13     5    Google  582409.04
# 14     5    Yandex  104018.48
# 15     6  Facebook   10731.34
# 16     6    Google  566744.76
# 17     6    Yandex  100234.94
# 18     7  Facebook    3092.88
# 19     7    Google  528411.08
# 20     7    Yandex  135466.40
# 21     8  Facebook    3107.56
# 22     8    Google  571182.04
# 23     8    Yandex  185396.40
# 24     9  Facebook    3002.60
# 25     9    Google  861336.92
# 26     9    Yandex  108959.06
# 27    10  Facebook    2895.12
# 28    10    Google  934553.24
# 29    10    Yandex  123349.32

# %% [markdown]
# ## Метрики
#
# `CMGR` = (Последний месяц / Первый месяц) ^ (1 / № месяцев) - 1
#
# `CAC` = Общая стоимость привлечения / Число новых пользователей
#
# `ARR` = средняя чистая прибыль/сумма первоначальных инвестиций.
#
# `S&M expense`
# ![alt text](https://www.thesaascfo.com/wp-content/uploads/2016/11/SaaS-Magic-Number-Formula.png)

# %%
cmgr = ()
